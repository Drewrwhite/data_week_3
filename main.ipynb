# %%
from faker import Faker

fake = Faker()

color_list = [fake.color_name() for x in range(20)]
# create list of 20 random color with faker
# uses list comp
print(color_list)
# Out:
# ['Aquamarine', 'Purple', 'Bisque', 'Pink', 'MediumOrchid', 'LimeGreen', 'Maroon', 'LavenderBlush', 'DarkRed', 'LightCyan', 'PeachPuff', 'Blue', 'BlanchedAlmond', 'LightSteelBlue', 'Blue', 'DarkOrchid', 'LightBlue', 'LemonChiffon', 'MidnightBlue', 'NavajoWhite']

# %%
test_list = [1, 1, 1, 5, 6, 7, 8, 9, 9, 10, 1, 2, 2]

def remove_dups(list1: list) -> None:
  """ Remove duplicates from list using dict comp

  Args:
      list1 (list): List to check for duplicates
  Return: 
      list with no duplicates
  """
  return list(dict.fromkeys(list1))

color_list = remove_dups(color_list)

print(color_list)

remove_dups()
# Out:
# ['Aquamarine', 'Purple', 'Bisque', 'Pink', 'MediumOrchid', 'LimeGreen', 'Maroon', 'LavenderBlush', 'DarkRed', 'LightCyan', 'PeachPuff', 'Blue', 'BlanchedAlmond', 'LightSteelBlue', 'DarkOrchid', 'LightBlue', 'LemonChiffon', 'MidnightBlue', 'NavajoWhite']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/65/b6m02_vj3fg2pjygj2rxntpm0000gn/T/ipykernel_32087/3762612924.py in <module>
#      15 print(color_list)
#      16
# ---> 17 remove_dups()
#      18
#
# TypeError: remove_dups() missing 1 required positional argument: 'list1'

# %%
color_dict = {color: len(color) for color in color_list}
# using dict comp to create dictionary where colors are keys and len is value
print(color_dict)
# Out:
# {'Aquamarine': 10, 'Purple': 6, 'Bisque': 6, 'Pink': 4, 'MediumOrchid': 12, 'LimeGreen': 9, 'Maroon': 6, 'LavenderBlush': 13, 'DarkRed': 7, 'LightCyan': 9, 'PeachPuff': 9, 'Blue': 4, 'BlanchedAlmond': 14, 'LightSteelBlue': 14, 'DarkOrchid': 10, 'LightBlue': 9, 'LemonChiffon': 12, 'MidnightBlue': 12, 'NavajoWhite': 11}

# %%
import json

with open("./data/color_dict.json", "w") as json_file:
  json.dump(color_dict, json_file, indent=4, skipkeys=True)

print("Done!")
# Out:
# Done!

# %%
import json

with open("./data/color_dict.json", "r") as json_file:
# open json file to read, load as color_dict
  color_dict = json.load(json_file)
# for keys and values in dict return string of all greater than or equal to 4
  for key, value in color_dict.items():
    if value >= 4:
      print (f"{key} is {value} letters")
# Out:
# Aquamarine is 10 letters
# Purple is 6 letters
# Bisque is 6 letters
# Pink is 4 letters
# MediumOrchid is 12 letters
# LimeGreen is 9 letters
# Maroon is 6 letters
# LavenderBlush is 13 letters
# DarkRed is 7 letters
# LightCyan is 9 letters
# PeachPuff is 9 letters
# Blue is 4 letters
# BlanchedAlmond is 14 letters
# LightSteelBlue is 14 letters
# DarkOrchid is 10 letters
# LightBlue is 9 letters
# LemonChiffon is 12 letters
# MidnightBlue is 12 letters
# NavajoWhite is 11 letters
